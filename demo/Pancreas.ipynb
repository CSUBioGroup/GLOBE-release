# %%
# %load_ext autoreload
# %autoreload 2


import os
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sps
import matplotlib.pyplot as plt

import sys
from os.path import join
from pathlib import Path
cur_dir = Path(os.getcwd())
sys.path.append(str(cur_dir.parent.absolute()))
from sklearn.preprocessing import normalize

from GLOBE.builder import GLOBE
from GLOBE.config import Config
from GLOBE.trainval import get_args

from GLOBE.prepare_dataset import prepare_dataset, prepare_mnn
from GLOBE.preprocessing import preprocess_data, embPipe, hvgPipe

configs = Config()

# %%
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)

args_dict = {"exp_id": 'Pancreas_0523',
            "mode": 'unsupervised', 
            "dname": "Pancreas",
             
            # pp params
            "select_hvg": True,
            "scale": False, 
             
            # network params 
            "block_level": 1,
            "lat_dim": 128,
            "proj_dim":64,
            "header":None,
            "init": 'uniform',
             
            # training params
            "use_knn": False,
            "add_noise": False,    # wheter to add noise for positives
            "loss_type": 'GLOBE',  # GLOBE or InfoNCE
            "temp": 0.1,
            "load_ckpt": False,
            "ckpt_idx": 2,
            "sup_eps": 100,
            "sup_lr": 1e-4,
            'unsup_eps': 80,
            "unsup_lr": 1e-5,
            "weight_decay":1e-4,
            "batch_size": 256,
            "plot_loss": True,
            "save_freq": 10,
            "gpu": '0',
            "num_workers": 6}

args = Struct(**args_dict)
args.lr = args.sup_lr if args.mode=='supervised' else args.unsup_lr
args.eps= args.sup_eps if args.mode=='supervised' else args.unsup_eps
args.mode = args.mode + '-' + args.loss_type  # to be optimized

# %%
args.dname
# Out:
# 'Pancreas'

# %%
# prepare dataset
sps_x, genes, cells, metadata = prepare_dataset(join(configs.data_root, args.dname))
anchor_data = prepare_mnn(join(configs.data_root, args.dname))  # loading anchors exported from seurat

# preprocessing
sps_x, pp_genes, pp_cells, pp_metadata, pp_anchor_data = preprocess_data(sps_x, 
                                                            cnames=cells, 
                                                            gnames=genes, 
                                                            metadata=metadata, 
                                                            anchor_data=anchor_data,
                                                            select_hvg=args.select_hvg, 
                                                            scale=args.scale)
# Out:
# The reading cost time 0.0331 secs
# reading Anchors from  /home/yxh/gitrepo/Batch-effect-removal-benchmarking-master/Script/sapling/GLOBE/data/Pancreas/seuratAnchors.csv
# ... storing 'batch' as categorical
# ... storing 'celltype_orig' as categorical
# ... storing 'celltype' as categorical
# /home/yxh/.local/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
sps_x.shape, pp_genes.shape, pp_cells.shape, pp_metadata.shape
# Out:
# ((14767, 2000), (2000,), (14767,), (14767, 6))

# %%
# init model
globe = GLOBE(
        mode=args.mode,          # supervised or unsupervised
        exp_id=args.exp_id,
        gpu=args.gpu,
    )

# %%
# create dataset and loader
globe.build_dataset(
    sps_x=sps_x, 
    gnames=pp_genes, 
    cnames=pp_cells, 
    metadata=pp_metadata, 
    anchor_data=pp_anchor_data,
    add_noise=args.add_noise,
    use_knn=args.use_knn
)

# initializing network
globe.build_model(
    lat_dim=args.lat_dim,
    proj_dim=args.proj_dim,
    header=args.header,
    block_level=args.block_level,
    init=args.init
)
# Out:
# building dataset
# building model

# %%
# training
globe.train(
    temp=args.temp,
    lr=args.lr,
    batch_size=args.batch_size,
    epochs=args.eps,
    plot_loss=args.plot_loss,
    save_freq=args.save_freq,
    weight_decay=args.weight_decay,
    num_workers=args.num_workers,
    view='double'
)
# Out:
# 100%|██████████| 58/58 [00:02<00:00, 20.41batch/s, loss=3.44]
# 100%|██████████| 58/58 [00:01<00:00, 33.16batch/s, loss=3.2]
# 100%|██████████| 58/58 [00:01<00:00, 32.06batch/s, loss=3.07]
# 100%|██████████| 58/58 [00:03<00:00, 17.91batch/s, loss=3.01]
# 100%|██████████| 58/58 [00:01<00:00, 34.42batch/s, loss=2.97]
# 100%|██████████| 58/58 [00:02<00:00, 19.71batch/s, loss=2.92]
# 100%|██████████| 58/58 [00:01<00:00, 32.20batch/s, loss=2.89]
# 100%|██████████| 58/58 [00:01<00:00, 33.46batch/s, loss=2.86]
# 100%|██████████| 58/58 [00:03<00:00, 18.94batch/s, loss=2.83]
# 100%|██████████| 58/58 [00:01<00:00, 33.50batch/s, loss=2.82]
# 100%|██████████| 58/58 [00:03<00:00, 17.66batch/s, loss=2.79]
# 100%|██████████| 58/58 [00:01<00:00, 34.54batch/s, loss=2.77]
# 100%|██████████| 58/58 [00:03<00:00, 19.11batch/s, loss=2.75]
# 100%|██████████| 58/58 [00:01<00:00, 30.97batch/s, loss=2.73]
# 100%|██████████| 58/58 [00:02<00:00, 21.52batch/s, loss=2.71]
# 100%|██████████| 58/58 [00:01<00:00, 33.96batch/s, loss=2.69]
# 100%|██████████| 58/58 [00:02<00:00, 26.32batch/s, loss=2.68]
# 100%|██████████| 58/58 [00:01<00:00, 34.87batch/s, loss=2.66]
# 100%|██████████| 58/58 [00:01<00:00, 35.16batch/s, loss=2.65]
# 100%|██████████| 58/58 [00:01<00:00, 35.34batch/s, loss=2.63]
# 100%|██████████| 58/58 [00:02<00:00, 23.51batch/s, loss=2.62]
# 100%|██████████| 58/58 [00:02<00:00, 22.29batch/s, loss=2.6]
# 100%|██████████| 58/58 [00:02<00:00, 23.60batch/s, loss=2.59]
# 100%|██████████| 58/58 [00:02<00:00, 21.39batch/s, loss=2.57]
# 100%|██████████| 58/58 [00:02<00:00, 22.48batch/s, loss=2.57]
# 100%|██████████| 58/58 [00:02<00:00, 22.91batch/s, loss=2.55]
# 100%|██████████| 58/58 [00:02<00:00, 21.88batch/s, loss=2.54]
# 100%|██████████| 58/58 [00:02<00:00, 21.80batch/s, loss=2.53]
# 100%|██████████| 58/58 [00:02<00:00, 21.92batch/s, loss=2.52]
# 100%|██████████| 58/58 [00:02<00:00, 22.63batch/s, loss=2.5]
# 100%|██████████| 58/58 [00:02<00:00, 20.96batch/s, loss=2.49]
# 100%|██████████| 58/58 [00:02<00:00, 21.37batch/s, loss=2.49]
# 100%|██████████| 58/58 [00:02<00:00, 21.17batch/s, loss=2.47]
# 100%|██████████| 58/58 [00:02<00:00, 21.04batch/s, loss=2.47]
# 100%|██████████| 58/58 [00:02<00:00, 22.99batch/s, loss=2.45]
# 100%|██████████| 58/58 [00:02<00:00, 22.77batch/s, loss=2.44]
# 100%|██████████| 58/58 [00:02<00:00, 20.37batch/s, loss=2.44]
# 100%|██████████| 58/58 [00:02<00:00, 21.01batch/s, loss=2.42]
# 100%|██████████| 58/58 [00:02<00:00, 22.52batch/s, loss=2.41]
# 100%|██████████| 58/58 [00:02<00:00, 22.20batch/s, loss=2.4]
# 100%|██████████| 58/58 [00:02<00:00, 22.82batch/s, loss=2.39]
# 100%|██████████| 58/58 [00:02<00:00, 21.65batch/s, loss=2.39]
# 100%|██████████| 58/58 [00:02<00:00, 22.04batch/s, loss=2.37]
# 100%|██████████| 58/58 [00:02<00:00, 21.60batch/s, loss=2.37]
# 100%|██████████| 58/58 [00:02<00:00, 22.36batch/s, loss=2.36]
# 100%|██████████| 58/58 [00:02<00:00, 21.90batch/s, loss=2.34]
# 100%|██████████| 58/58 [00:02<00:00, 21.28batch/s, loss=2.34]
# 100%|██████████| 58/58 [00:02<00:00, 22.72batch/s, loss=2.33]
# 100%|██████████| 58/58 [00:02<00:00, 22.18batch/s, loss=2.33]
# 100%|██████████| 58/58 [00:02<00:00, 24.53batch/s, loss=2.31]
# 100%|██████████| 58/58 [00:02<00:00, 21.35batch/s, loss=2.31]
# 100%|██████████| 58/58 [00:02<00:00, 22.24batch/s, loss=2.3]
# 100%|██████████| 58/58 [00:02<00:00, 22.83batch/s, loss=2.29]
# 100%|██████████| 58/58 [00:02<00:00, 21.02batch/s, loss=2.28]
# 100%|██████████| 58/58 [00:02<00:00, 21.28batch/s, loss=2.27]
# 100%|██████████| 58/58 [00:02<00:00, 21.48batch/s, loss=2.27]
# 100%|██████████| 58/58 [00:02<00:00, 21.78batch/s, loss=2.27]
# 100%|██████████| 58/58 [00:02<00:00, 23.28batch/s, loss=2.25]
# 100%|██████████| 58/58 [00:02<00:00, 23.23batch/s, loss=2.25]
# 100%|██████████| 58/58 [00:02<00:00, 22.16batch/s, loss=2.24]
# 100%|██████████| 58/58 [00:02<00:00, 23.45batch/s, loss=2.22]
# 100%|██████████| 58/58 [00:02<00:00, 21.55batch/s, loss=2.22]
# 100%|██████████| 58/58 [00:02<00:00, 21.15batch/s, loss=2.22]
# 100%|██████████| 58/58 [00:02<00:00, 21.89batch/s, loss=2.21]
# 100%|██████████| 58/58 [00:02<00:00, 20.99batch/s, loss=2.2]
# 100%|██████████| 58/58 [00:02<00:00, 21.50batch/s, loss=2.2]
# 100%|██████████| 58/58 [00:02<00:00, 22.96batch/s, loss=2.19]
# 100%|██████████| 58/58 [00:02<00:00, 21.93batch/s, loss=2.2]
# 100%|██████████| 58/58 [00:02<00:00, 21.65batch/s, loss=2.19]
# 100%|██████████| 58/58 [00:02<00:00, 20.58batch/s, loss=2.17]
# 100%|██████████| 58/58 [00:02<00:00, 22.57batch/s, loss=2.17]
# 100%|██████████| 58/58 [00:02<00:00, 21.21batch/s, loss=2.16]
# 100%|██████████| 58/58 [00:02<00:00, 22.25batch/s, loss=2.16]
# 100%|██████████| 58/58 [00:02<00:00, 22.35batch/s, loss=2.15]
# 100%|██████████| 58/58 [00:02<00:00, 21.15batch/s, loss=2.14]
# 100%|██████████| 58/58 [00:02<00:00, 23.17batch/s, loss=2.14]
# 100%|██████████| 58/58 [00:02<00:00, 22.55batch/s, loss=2.13]
# 100%|██████████| 58/58 [00:02<00:00, 21.52batch/s, loss=2.12]
# 100%|██████████| 58/58 [00:02<00:00, 21.64batch/s, loss=2.12]
# 100%|██████████| 58/58 [00:02<00:00, 20.80batch/s, loss=2.11]

# %%
args.lr
# Out:
# 1e-05

# %%
# loading checkpoints
globe.load_ckpt(30)

# inference
lat_data, _, metadata1 = globe.evaluate(batch_size=args.batch_size, num_workers=args.num_workers)
emb_data = normalize(lat_data, axis=1)

ad_e = embPipe(emb_data, metadata1)
sc.pl.umap(ad_e, color=[configs.batch_key, configs.label_key])
# Out:
# => loaded unsupervised-GLOBE checkpoint 30
